# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("gld_price_data.csv")

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.shape
# Out:
# (2290, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
df.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
from datetime import datetime

df['Date'] = df['Date'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y'))
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0    2008-01-02  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1    2008-01-03  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2    2008-01-04  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3    2008-01-07  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4    2008-01-08  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285 2018-05-08  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286 2018-05-09  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287 2018-05-10  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288 2018-05-14  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289 2018-05-16  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap = "copper")
# Out:
# <style type="text/css">
# #T_c88bb_row0_col0, #T_c88bb_row1_col1, #T_c88bb_row2_col2, #T_c88bb_row3_col3, #T_c88bb_row4_col4, #T_c88bb_row5_col5 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_c88bb_row0_col1 {
#   background-color: #ffc17b;
#   color: #000000;
# }
# #T_c88bb_row0_col2, #T_c88bb_row2_col3 {
#   background-color: #69422a;
#   color: #f1f1f1;
# }
# #T_c88bb_row0_col3, #T_c88bb_row0_col5, #T_c88bb_row1_col4, #T_c88bb_row3_col2, #T_c88bb_row5_col0, #T_c88bb_row5_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c88bb_row0_col4 {
#   background-color: #19100a;
#   color: #f1f1f1;
# }
# #T_c88bb_row1_col0 {
#   background-color: #ffc27b;
#   color: #000000;
# }
# #T_c88bb_row1_col2 {
#   background-color: #3e2719;
#   color: #f1f1f1;
# }
# #T_c88bb_row1_col3 {
#   background-color: #21150d;
#   color: #f1f1f1;
# }
# #T_c88bb_row1_col5 {
#   background-color: #150d08;
#   color: #f1f1f1;
# }
# #T_c88bb_row2_col0 {
#   background-color: #b17047;
#   color: #f1f1f1;
# }
# #T_c88bb_row2_col1 {
#   background-color: #885637;
#   color: #f1f1f1;
# }
# #T_c88bb_row2_col4 {
#   background-color: #ffb372;
#   color: #000000;
# }
# #T_c88bb_row2_col5 {
#   background-color: #875536;
#   color: #f1f1f1;
# }
# #T_c88bb_row3_col0 {
#   background-color: #010100;
#   color: #f1f1f1;
# }
# #T_c88bb_row3_col1 {
#   background-color: #0f0906;
#   color: #f1f1f1;
# }
# #T_c88bb_row3_col4, #T_c88bb_row4_col0 {
#   background-color: #6d452c;
#   color: #f1f1f1;
# }
# #T_c88bb_row3_col5, #T_c88bb_row5_col3 {
#   background-color: #ffb473;
#   color: #000000;
# }
# #T_c88bb_row4_col1 {
#   background-color: #4a2f1e;
#   color: #f1f1f1;
# }
# #T_c88bb_row4_col2 {
#   background-color: #ffb171;
#   color: #000000;
# }
# #T_c88bb_row4_col3 {
#   background-color: #a86a44;
#   color: #f1f1f1;
# }
# #T_c88bb_row4_col5 {
#   background-color: #c47c4f;
#   color: #f1f1f1;
# }
# #T_c88bb_row5_col2 {
#   background-color: #2a1b11;
#   color: #f1f1f1;
# }
# #T_c88bb_row5_col4 {
#   background-color: #935d3b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c88bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c88bb_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_c88bb_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_c88bb_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_c88bb_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_c88bb_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_c88bb_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c88bb_level0_row0" class="row_heading level0 row0" >Date</th>
#       <td id="T_c88bb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c88bb_row0_col1" class="data row0 col1" >0.944033</td>
#       <td id="T_c88bb_row0_col2" class="data row0 col2" >0.209118</td>
#       <td id="T_c88bb_row0_col3" class="data row0 col3" >-0.782230</td>
#       <td id="T_c88bb_row0_col4" class="data row0 col4" >-0.174108</td>
#       <td id="T_c88bb_row0_col5" class="data row0 col5" >-0.794540</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row1" class="row_heading level0 row1" >SPX</th>
#       <td id="T_c88bb_row1_col0" class="data row1 col0" >0.944033</td>
#       <td id="T_c88bb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c88bb_row1_col2" class="data row1 col2" >0.049345</td>
#       <td id="T_c88bb_row1_col3" class="data row1 col3" >-0.591573</td>
#       <td id="T_c88bb_row1_col4" class="data row1 col4" >-0.274055</td>
#       <td id="T_c88bb_row1_col5" class="data row1 col5" >-0.672017</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row2" class="row_heading level0 row2" >GLD</th>
#       <td id="T_c88bb_row2_col0" class="data row2 col0" >0.209118</td>
#       <td id="T_c88bb_row2_col1" class="data row2 col1" >0.049345</td>
#       <td id="T_c88bb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c88bb_row2_col3" class="data row2 col3" >-0.186360</td>
#       <td id="T_c88bb_row2_col4" class="data row2 col4" >0.866632</td>
#       <td id="T_c88bb_row2_col5" class="data row2 col5" >-0.024375</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row3" class="row_heading level0 row3" >USO</th>
#       <td id="T_c88bb_row3_col0" class="data row3 col0" >-0.782230</td>
#       <td id="T_c88bb_row3_col1" class="data row3 col1" >-0.591573</td>
#       <td id="T_c88bb_row3_col2" class="data row3 col2" >-0.186360</td>
#       <td id="T_c88bb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c88bb_row3_col4" class="data row3 col4" >0.167547</td>
#       <td id="T_c88bb_row3_col5" class="data row3 col5" >0.829317</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row4" class="row_heading level0 row4" >SLV</th>
#       <td id="T_c88bb_row4_col0" class="data row4 col0" >-0.174108</td>
#       <td id="T_c88bb_row4_col1" class="data row4 col1" >-0.274055</td>
#       <td id="T_c88bb_row4_col2" class="data row4 col2" >0.866632</td>
#       <td id="T_c88bb_row4_col3" class="data row4 col3" >0.167547</td>
#       <td id="T_c88bb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c88bb_row4_col5" class="data row4 col5" >0.321631</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row5" class="row_heading level0 row5" >EUR/USD</th>
#       <td id="T_c88bb_row5_col0" class="data row5 col0" >-0.794540</td>
#       <td id="T_c88bb_row5_col1" class="data row5 col1" >-0.672017</td>
#       <td id="T_c88bb_row5_col2" class="data row5 col2" >-0.024375</td>
#       <td id="T_c88bb_row5_col3" class="data row5 col3" >0.829317</td>
#       <td id="T_c88bb_row5_col4" class="data row5 col4" >0.321631</td>
#       <td id="T_c88bb_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(corr['GLD'])
df.hist(figsize=(24, 4), layout=(1, 6), color="g");
# Out:
# Date       0.209118
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
sns.pairplot(df.sample(n=100));
# Out:
# C:\Users\suzan\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data_preprocessed = df.copy()

# %%
data_preprocessed.isnull().mean() * 100
# Out:
# Date       0.0
# SPX        0.0
# GLD        0.0
# USO        0.0
# SLV        0.0
# EUR/USD    0.0
# dtype: float64

# %%
date_columns = ['Date']
num_columns = data_preprocessed.select_dtypes(include=['float64', 'int64']).columns
target_col = 'GLD'

# %%
num_columns
# Out:
# Index(['SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
data_preprocessed['Date'] = pd.to_datetime(data_preprocessed['Date'])

# %%
data_preprocessed.reset_index(drop=True, inplace=True)

# %%
data_preprocessed.drop(['Date'], axis=1, inplace=True)

